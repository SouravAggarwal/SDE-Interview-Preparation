# %%
Content
1. Docker File

# %% [markdown]
# # 1. Docker File

# %%
1. Dockerfile: A text file with instructions for installing and configuring
2. Image (Snapshot): Created by building a Dockerfile and ready to be made live.
3. Container (A live instance): A running isolated environment created from an image.
