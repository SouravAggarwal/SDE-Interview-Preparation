# %%
Content
1. UML Diagrams

# %% [markdown]
# # 1. UML Diagrams

# %% [markdown]
# ![image.png](attachment:97a0c648-3eb3-4d9a-a7d7-0e9743c8840c.png)

# %% [markdown]
# # Relation b/w classes
# ### UML Notation
# ![image.png](attachment:24b14197-6ccf-4a45-a06b-0a874ba2842d.png)

# %%
Company  ◆──────────────  Team  ◇──────────────  Player
         <<composition>>        <<aggregation>>
- Company own the team and team has players.
