# %%
Theory questions:
1. N*M chocolotes, two persons are breaking the chocolate one by one, how many total turns will be there.
(N*M) - 1

P&C
1. There are 4 fruits in a box,
 - Select any two fruits out of them without considering the order: nCr => n! / ((r!) (n-r)!)
 - If we want to arrange objects in a specific order: n! / (n-r)!

- nCr = nC(n-r)
- nCn = nC0 = 1

- All items are different, each item can be included or excluded => (2^n) -1
- There are 5 A, 7 B, and 3 different unique items
   A can be selected by 0,1,2,3,4,5 ways

# %%
# Link List structure cons
-  Linklist and trees are cache inefficient
- Array/ Contigous blocks are cache efficient.

- Arrays are indexed and element can be fetched in O(1) time.
- Tree in array:
  left child index: i * 2 +1
  right child index: i * 2 + 2
  parent: (i-1) / 2

- Array usecase
  -  when we know we need a contigous space and total size is fixed.

- Linklist usecase
  - Dynamic memory allocation
  - Efficient insert/ delete
  - No memory wastage

- In python
   - int and float takes 8 bytes
   - character takes 1 bytes
   - 8 bytes for a pointer 
   - float has size of 16 bytes

# %%
import sys
x = 10000
a = [1, 2 ]
print("size of integer", sys.getsizeof(x))
print("size of 2 characters", sys.getsizeof(2.3))

print("size of list with 2 ints", sys.getsizeof(a))
# Out:
# size of integer 28
# size of 2 characters 24
# size of list with 2 ints 72

# %%
# Python list Insertion and Deletion.
# deque takes O(1) from both ends, where as List takes O(N)

from collections import deque
a = deque([1, 2, 3, 4, 5])
a.append(6)
a.pop()
a.appendleft(0) # Append at start
a.popleft() # Pop from start

b = [1,2,3,4,5]
b.append(6)
b.pop()
b.insert(0, 10)
b.pop(0)


x = set()
x.add(4)
x.remove(4)
print(x)

y = set()
y.add(tuple([1,2]))
y.add((2,3))
print(y)


a = dict()
a['q'] = 1
a.pop('q', None) # Removes key, returns default if missing
# Out:
# deque([1, 2, 3, 4, 5])

# %%
# try/ except
try:
    num = int("abc")
except ValueError:
    print("Invalid number")
except ZeroDivisionError:
    print("Divide by zero")
