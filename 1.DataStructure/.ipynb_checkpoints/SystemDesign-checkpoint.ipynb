# %%
Temp data storage:
    Redis: Caching
    S3: File storage system (images/ videos)
    CDN: Content delivery network (Distributing same image into multiple geographical locations)
    Text search Engine: Elastic Search/ Solar
    Fuzzy search: Search text with wrong spelling (Edit distance: 2, No. of characters different from actual to user typed)

Time Series Database:
- Write in append mode only, when new time is greater than all previous time.
- Bulk Read query.

Analytics on Data of complete company:
- Data warehouse: You put a lot of data from various transactions, geography, orders.
- Ex: Hadoop

Persistant Database:
- Structure Information
    Yes
     |
     |
    Need ACID
    Yes
     |
     |
- RDBMS (Postgress, mysql): When we have structure data and we need ACID properties.
- Document DB (Mongo DB): When we do not have structure data, and there are so many datatypes and different queries.
- Columnar DB (Casandra, HBase): Ever increasing data (data increasing in exponantial), like Uber driver location, but less or finite number of queries.

# %% [markdown]
# # System Design - Google Maps

# %%
Non Functional Requirement:
- High Availablity
- Good Accuracy
- Not too slow

User Base:
- 1 Billion users per day
It should be plug and play model:
- Information about whether, road blocked, accident.


Functional Requirement:
- From Point A to B: we will just show time and distance, route.

- Ask govt or organisation.
- Add a new road based on user data.
