# %%
✅ Must-know Core Concepts
	•	What is Generative AI? (definition + use cases)
	•	Difference between AI, ML, Deep Learning, GenAI
	•	How LLMs work (Transformers, embeddings, attention)
	•	Prompt Engineering basics (how input affects output)
	•	CAP theorem vs Vector DBs (often asked in GenAI system design)
	•	Ethical challenges (bias, hallucinations, misuse).

✅ Hands-on (Good for Projects/Portfolio)
	•	Use OpenAI API (ChatGPT, DALL·E)
	•	Use Hugging Face models (transformers, stable diffusion)
	•	Implement RAG (Retrieval-Augmented Generation) → combining LLMs with a database (often asked in interviews).
	•	Play with LangChain or LlamaIndex → frameworks for building GenAI apps.

✅ Knowledge Areas Interviewers Look For
	1.	LLMs → what they are, how they’re trained, limitations.
	2.	Vector Databases (Pinecone, Weaviate, FAISS, Milvus) → used for storing embeddings.
	3.	Scaling GenAI Apps → caching, sharding, latency issues.
	4.	Evaluation → how do you measure correctness when the output is probabilistic?


	•	What is Generative AI, and how is it different from traditional AI/ML?
	•	Explain how transformers work in LLMs.
	•	What is Retrieval-Augmented Generation (RAG), and why is it needed?
	•	What are embeddings, and how are they stored/retrieved?
	•	How would you design a chatbot that answers from company documents?
	•	What are risks of using GenAI in production?
