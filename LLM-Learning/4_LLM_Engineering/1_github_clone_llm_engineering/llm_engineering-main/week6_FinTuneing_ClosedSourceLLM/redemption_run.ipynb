# %% [markdown]
# # Week 6 Optional Extra - Deep Neural Network
#
# Just to redeem ourselves from the disappointing result
#
# I trained the Deep Neural Network in pricer/deep_neural_network.py and I've uploaded weights here. Download this file to the week6 directory:
#
# The file `deep_neural_network.pth` here:
#
# https://drive.google.com/drive/folders/1uq5C9edPIZ1973dArZiEO-VE13F7m8MK?usp=drive_link

# %%
from dotenv import load_dotenv
import os
from huggingface_hub import login
from pricer.evaluator import evaluate
from pricer.deep_neural_network import DeepNeuralNetworkRunner
from pricer.items import Item

# %%
# environment

LITE_MODE = True

load_dotenv(override=True)
hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
username = "ed-donner"
dataset = f"{username}/items_lite" if LITE_MODE else f"{username}/items_full"

train, val, test = Item.from_hub(dataset)

print(f"Loaded {len(train):,} training items, {len(val):,} validation items, {len(test):,} test items")
# Out:
# Using the latest cached version of the dataset since ed-donner/items_lite couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /Users/sourav/.cache/huggingface/datasets/ed-donner___items_lite/default/0.0.0/057ae6b7731e35538897c976e391e76fbb729006 (last modified on Sat Jan  3 14:03:48 2026).
# Loaded 20,000 training items, 1,000 validation items, 1,000 test items

# %%
runner = DeepNeuralNetworkRunner(train, val[:1000])
runner.setup()
# Out:
# Deep Neural Network created with 289,128,449 parameters
# Using mps

# %% [markdown]
# ## If you want to train this yourself
#
# Then run this - it takes about 4 hours on my M1 Mac hammering the GPU:
#
# ```python
# runner.train(epochs=5)
# runner.save('deep_neural_network.pth')
# ```
#
# ## Or just download the file `deep_neural_network.pth` here:
#
# https://drive.google.com/drive/folders/1uq5C9edPIZ1973dArZiEO-VE13F7m8MK?usp=drive_link
#
# And put it in this week6 directory.

# %%
runner.load('deep_neural_network.pth')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 runner.load('deep_neural_network.pth')
#
# File ~/Personal/Projects/Learning/LLMProjects/3_LLM_Engineering/1_github_clone_llm_engineering/llm_engineering-main/week6_FinTuneing_ClosedSourceLLM/pricer/deep_neural_network.py:164, in DeepNeuralNetworkRunner.load(self, path)
#     163 def load(self, path):
# --> 164     self.model.load_state_dict(torch.load(path))
#     165     self.model.to(self.device)
#
# File ~/Personal/Projects/Learning/LLMProjects/3_LLM_Engineering/1_github_clone_llm_engineering/llm_engineering-main/.venv/lib/python3.12/site-packages/torch/serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
#    1489         orig_position = opened_file.tell()
#
# File ~/Personal/Projects/Learning/LLMProjects/3_LLM_Engineering/1_github_clone_llm_engineering/llm_engineering-main/.venv/lib/python3.12/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~/Personal/Projects/Learning/LLMProjects/3_LLM_Engineering/1_github_clone_llm_engineering/llm_engineering-main/.venv/lib/python3.12/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'deep_neural_network.pth'

# %%
def deep_neural_network(item):
    return runner.inference(item)

evaluate(deep_neural_network, test)
