# %%
Content
1. Introduction to Agents

# %%
Course Introduction
1. Introduction to Agents: Explore the foundational concepts of Al agents, their defining characteristics, and how agentic architectures differ from traditional LLM applications, laying the groundwork for building intelligent, autonomous systems.
2. Agent Tools & Interoperability with MCP: Dive into the world of tools, understanding how Al agents can take action by leveraging external functionalities and APls, and explore the ease of discovering and using tools offered by the Model Context Protocol (MCP).
3. Context Engineering: Sessions & Memory:  Explore how to build Al agents that can remember past interactions and maintain context. Learn how to implement short-term and long-term memory to create more robust agents capable of handling amnloy multiten tachc complex, multi-turn tasks.
4. Agent Quality: Learn to build robust and reliable Al agents by mastering the critical disciplines of evaluating and improving agents. This session will cover observability, logging, and tracing to provide visibility, alongside key metrics and evaluation strategies to optimize agent performance.
5. Prototype to Production: Go beyond local testing and learn to deploy and scale Al agents for real-world use. This session will cover the best practices for deploying your agents so that others can use them, including how to create a truly multi-agent system with the Agent2Agent (A2A) Protocol.

1. Introduction to Agents
    → Core Agent Architecture (Model, Tools, Orchestration)
    → The "Think, Act, Observe" Problem-Solving Loop
    → Taxonomy of Agentic Systems (Levels 0-4)
    → Multi-Agent Systems & Design Patterns
    → Agent Interoperability (Human, A2A, Commerce)
    → Security: Agent Identity & Governance

# %%
LLM: can only generate text.
Agents: Can accomplish a complex task.

Agent Task Example:
1. Get the mission/ Get the high level goal
2. Check what tools the LLM has (API access, function calling), what's relevant in the memeory.
3. Planning stage (think it through):
    - Ex: to plan a trip, you need basic info (No. of people, places)
4. Take action
    - It might call the api to get the list of team info.
5. Observe and iterate.

# %% [markdown]
# # 1. Introduction to Agents

# %%
Course Introduction
1. Introduction to Agents: Explore the foundational concepts of Al agents, their defining characteristics, and how agentic architectures differ from traditional LLM applications, laying the groundwork for building intelligent, autonomous systems.
2. Agent Tools & Interoperability with MCP: Dive into the world of tools, understanding how Al agents can take action by leveraging external functionalities and APls, and explore the ease of discovering and using tools offered by the Model Context Protocol (MCP).
3. Context Engineering: Sessions & Memory:  Explore how to build Al agents that can remember past interactions and maintain context. Learn how to implement short-term and long-term memory to create more robust agents capable of handling amnloy multiten tachc complex, multi-turn tasks.
4. Agent Quality: Learn to build robust and reliable Al agents by mastering the critical disciplines of evaluating and improving agents. This session will cover observability, logging, and tracing to provide visibility, alongside key metrics and evaluation strategies to optimize agent performance.
5. Prototype to Production: Go beyond local testing and learn to deploy and scale Al agents for real-world use. This session will cover the best practices for deploying your agents so that others can use them, including how to create a truly multi-agent system with the Agent2Agent (A2A) Protocol.
