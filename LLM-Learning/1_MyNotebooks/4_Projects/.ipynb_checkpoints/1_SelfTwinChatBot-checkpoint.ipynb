# %%
Content
1. HLD

# %% [markdown]
# # 1. HLD

# %% [markdown]
# ![image.png](attachment:69b9d1a4-9a8a-4bc1-b797-51f97c98d55b.png)

# %%
Setup and Code: https://github.com/ed-donner/production/blob/main/week2/day1.md
