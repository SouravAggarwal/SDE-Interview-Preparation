# %%
Content
1. Aware about the business problem
2. Strategy for Development
3. Metric for Testing

# %% [markdown]
# # 1. Aware about the business problem

# %%
# Questions
1. What business problem are you solving?
2. How will you measure success?
3. What data do you have, and what data do you need?

# %% [markdown]
# # 2. Strategy for Development

# %%
# To selecting, training and applying an LLM to a commercial problem
Step 1: Understand business problem and how do you measure sucess.
    - Gather business requirements for the task
    - Identify performance criteria
        - Model and Business Centric metrics
    - Understand the data: quantity, quality, format
    - Determine non-functionals
        - Cost constraints, scalability, latency
        - R&D / build budget and implementation timeline

Step 2: Prepare
    - Approach: Send the raw text to LLM, and ask the LLM to summarize it and return a JSON with product description and other details.
    - Research existing / non-LLM solutions
        - Potential baseline model
    - Compare relevant LLMs
        - The basics, including context length, price and license
        - Benchmarks, Leaderboards and Arenas
        - Specialist scores for the task at hand
    - Curate data: clean, preprocess and split
        
Step 3: Choose the model according to the business requirement and check leaderboard for model comparisons.
    - For a coding language converter, go to benchmark websites and check for coding performance metric.
    
Step 4: Select a few models and test all model prototypes for the business requirement.
    - Test with Training and validation data, which model fits the best.
            
Step 5: Customize: Using tools, RAG, Prompts 
    - Techniques to optimize the performance of the model
        1. Inference Time
            - Improve Prompt
            - RAG
            - Agents
        2. Training Time
            - Fine-tune LLM
             
Step 6: Production Deployment
    - Determine API between model and platform(s)
    - Identify model hosting and deployment architecture
    - Address scaling, monitoring, security, compliance, observability
    - Evals: measure the Business-Focused Metrics identified in step 1
    - Continuously retrain and measure performance

# %%
### Development with Model Training
Step 1: Curate the data
Step 2: Pre-process the data
Step 3: Baseline Models & Traditional ML
Step 4: Neural Networks and Frontier LLMs
Step 5: Fine-Tuned Frontier/ OpenSource LLM
Step 6: Deploy

# %% [markdown]
# ### Step 1: Curate the data

# %%
1. Investigate to find the data
2. Parse
3. Visualize
4. Assess Data Quality
5. Curate
6. Save

# Data Split
1. Training Data
2. Validation Data
3. Test Data

# %% [markdown]
# # 3. Metric for Testing

# %%
1. Model-centric or Technical Metrics "Loss"
2. Business-centric or Outcome Metrics (Actual Differences in Output of Model vs Real world data).
