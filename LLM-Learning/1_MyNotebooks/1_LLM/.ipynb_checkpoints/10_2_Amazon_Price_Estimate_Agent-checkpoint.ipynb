# %%
Content
1. Agent Architecture

# %% [markdown]
# # 1. Agent Architecture

# %% [markdown]
# ![image.png](attachment:21599559-7007-439d-bba3-203413d91528.png)

# %%
Project: Given a description of a product, estimate its price.
    - Use a Fine-Tune Model open source Llama 3.2 model, trained to 800K dataset
    - Use RAG with a Frontier model, RAG will be used to find 5 similar products and then it will be given to LLM, for price estimation.
    - Another Agent, to send notification.
    - To predict price, Use ensemble approach, prediction of multiple models and then take average.
        - RAG with GPT 5.1 Model, Specialist Agent (fine-tunned model), Raw Neural Network Agent.
        - Preprocess the query user with the help of a LLM.
