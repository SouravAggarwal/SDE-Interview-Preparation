# %%
Content
 - Introduction

# %% [markdown]
# # 1. Introduction

# %%
Hugging Face APIs

# Levels of APIs
1. Higher level APIs: to carry out standard tasks quickly
2. Lower level APIs: to provide more control and power (Tokenizers and Models)
