# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
# Out:
# /Volumes/Personal/Projects/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Generation**: Generative AI can be used to generate high-quality content such as articles, social media posts, product descriptions, and more. This can help businesses save time and resources while maintaining a consistent tone and style.
# 2. **Image and Video Creation**: Generative AI can create realistic images and videos that can be used for marketing, advertising, and entertainment purposes. For example, generating product images or creating music videos.
# 3. **Chatbots and Virtual Assistants**: Generative AI can power chatbots and virtual assistants, enabling businesses to provide 24/7 customer support and improve user engagement.
# 4. **Predictive Maintenance**: Generative AI can analyze sensor data from equipment and predict when maintenance is required, reducing downtime and increasing overall efficiency.
# 5. **Personalized Recommendations**: Generative AI can be used to generate personalized product recommendations based on customer behavior, preferences, and demographics.
# 6. **Automated Translation**: Generative AI can automatically translate text and speech in real-time, enabling businesses to expand into new markets and communicate with customers across languages.
# 7. **Marketing Campaign Optimization**: Generative AI can analyze market trends, consumer behavior, and campaign data to optimize marketing campaigns and improve ROI.
# 8. **Product Design and Development**: Generative AI can help design and develop new products by generating 3D models, prototypes, and testing scenarios.
# 9. **Supply Chain Management**: Generative AI can analyze supply chain data to predict demand, optimize inventory levels, and reduce lead times.
# 10. **Cybersecurity Threat Detection**: Generative AI can analyze network traffic and system logs to detect potential security threats and vulnerabilities.
#
# Some notable business applications of Generative AI include:
#
# * **Google's Bard**: A language model that generates human-like responses to user queries.
# * **Amazon's Reverb**: A generative AI platform for creating personalized product recommendations.
# * **Microsoft's Azure AI**: A suite of AI services, including generative models, for building intelligent applications.
# * **Adobe's Sensei**: A cloud-based generative AI platform for creative professionals.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses in various industries and domains.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can create high-quality content such as:
#  * Articles, blog posts, and social media posts
#  * Product descriptions and sales copy
#  * Email newsletters and marketing campaigns
#  * Music, videos, and audio tracks
# 2. **Image and Video Editing**: AI-powered tools can edit and enhance images and videos, including:
#  * Image retouching and manipulation
#  * Object removal and superimposition
#  * Color correction and grading
#  * Video editing and motion graphics
# 3. **Customer Service Chatbots**: Generative AI can power chatbots that:
#  * Answer customer queries and provide support
#  * Route complex issues to human agents
#  * Provide personalized recommendations and product suggestions
# 4. **Marketing Automation**: AI-generated content and personalized messages can be used in:
#  * Email marketing campaigns
#  * Social media advertising
#  * Influencer marketing
# 5. **Product Design and Development**: Generative AI can assist with:
#  * Product design and prototyping
#  * Materials science and materials selection
#  * 3D printing and additive manufacturing
# 6. **Financial Analysis and Forecasting**: Generative AI can analyze large datasets to predict:
#  * Market trends and sentiment analysis
#  * Customer behavior and purchasing patterns
#  * Stock prices and portfolio optimization
# 7. **Creative Writing and Storytelling**: AI-generated content can be used in:
#  * Advertising and marketing campaigns
#  * Brand storytelling and brand voice development
#  * Content creation for entertainment and media production
# 8. **Data Analysis and Visualization**: Generative AI can help analyze and visualize complex data, including:
#  * Data science and machine learning model training
#  * Business intelligence and data visualization tools
# 9. **Supply Chain Optimization**: Generative AI can optimize supply chain operations by:
#  * Predicting demand and inventory levels
#  * Identifying bottlenecks and inefficiencies
# 10. **Healthcare and Biotechnology**: Generative AI can help with:
#  * Medical imaging analysis and diagnosis
#  * Personalized medicine and treatment recommendations
#  * Research and development in biotech and pharmaceuticals
#
# These are just a few examples of the many business applications of generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across industries.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI has numerous business applications, including:
#
# 1. **Content Generation**: Automated content creation for social media, blogs, and websites using text or image generation models like language models (e.g., ChatGPT) or generative adversarial networks (GANs).
# 2. **Marketing Automation**: Personalized product recommendations, product images, and copywriting using AI-generated content.
# 3. **Customer Service Chatbots**: AI-powered chatbots that use natural language processing (NLP) to respond to customer inquiries, providing 24/7 support.
# 4. **Data Analysis and Visualization**: Automatically generating reports, charts, and graphs from large datasets using machine learning algorithms like Generative Adversarial Networks (GANs) or Variational Autoencoders (VAEs).
# 5. **Product Design**: AI-assisted product design, such as generating 3D models or designs for clothing, automotive parts, or architectural structures.
# 6. **Influencer Marketing**: Algorithmic modeling to predict influencer reach and engagement, ensuring successful influencer partnerships.
# 7. **Speech Recognition Systems**: Developing more accurate speech recognition systems using generative AI, which improves voice assistants' performance in noisy environments.
# 8. **Digital Audio and Music Generation**: Creating music from mathematical formulas or generating human-like voices for digital audio applications (e.g., dubstep music generation).
# 9. **Image Processing and Editing**: Automating image editing tasks like object removal or enhancement using generative models, which speed up content creation and post-production.
# 10. **Predictive Maintenance**: Using data analytics and machine learning to predict equipment failures, enabling proactive maintenance scheduling.
# 11. **Virtual Reality (VR) Experience Design**: Creating immersive VR experiences with AI-powered tools for scene generation, character animation, or interactive storytelling.
# 12. **Intelligent Virtual Assistants**: Developing conversational interfaces that use AI-generated responses to answer users' queries more efficiently and effectively.
#
# Businesses can leverage these AI applications to:
#
# * Increase efficiency
# * Enhance customer experience
# * Reduce costs
# * Improve product design and development
# * Extract valuable insights from large datasets
# * Drive revenue growth through innovative marketing strategies

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.
