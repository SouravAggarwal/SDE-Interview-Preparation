# %%
Content
1. Setup
2. Configure
3. Gemini/ OpenAI API Setup
4. Run Ollama Locally
5. LLM Models

# %% [markdown]
# # 1. Setup

# %%
# Create and activate conda env
conda env create -f /Volumes/Personal/Projects/LLMProjects/LLM_Engineering/llm_engineering/environment.yml 
conda activate llms

# %% [markdown]
# # 2. Configure

# %%
1. Gemini API Studio
    https://aistudio.google.com/app/usage?project=gen-lang-client-0234295121

2. Ollma Models download
    https://ollama.com/search

3. Open AI API Studio
    https://platform.openai.com/settings/organization/api-keys

# %% [markdown]
# # 3. Gemini/ OpenAI API Setup

# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai

# Load .env file
load_dotenv()

genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# Create a model instance
model = genai.GenerativeModel("gemini-2.5-flash")

# Generate content
response = model.generate_content("Explain how AI works in a few words")

# Print response text
print(response.text)
# Out:
# AI learns patterns from data to make decisions or predictions.

# %% [markdown]
# # 4. Run Ollama Locally

# %%
# Download Ollama UI
  https://ollama.com/

# Downalod Ollama Models
    https://ollama.com/search

# Command to download Ollama Models
    ollama run llama3.2 

# Verify if Ollama is running
    http://localhost:11434/

# Tokenizer
    https://platform.openai.com/tokenizer

# %% [markdown]
# # 5. LLM Models

# %%
# Closed Source Models
 - GPT from OpenAl
 - Claude from Anthropic
 - Gemini from Google
 - Command R from Cohere
 - Perplexity

# Open-Source Models
 - Llama from Meta
 - Mixtral from Mistral
 - Qwen from Alibaba Cloud
 - Gemma from Google
 - Phi from Microsoft

# %%
# Ways to use Models
1. Chat interfaces: like ChatGPT
2. Cloud API, LLM APIs
    - LLM API
        - ChatGPT, Gemini API: Pay per api call.
    - Managed AI Cloud Service
        - Use can use open/ closed source model, but model running in amazon server.
        - Amazon Bedrock, Google Vertex, Azure ML
3. Direct Inference
    - With Ollama to run locally

# %%
# How to Improve Prompts, to get better Information
1. Multi-shot Prompting
2. Use of tools
3. Additional context (system message with background context, or better assign a role to the system.)
4. RAG
