# %%
# Content
1. Topics
1. Design Pattern Resources
2. System Design Resources
3. HR/ Leadership Principles

# %% [markdown]
# # 1. Topics

# %%
1. Data Structure
    - Arrays, Strings, Hashing
    - Linked Lists, Stacks, Queues
    - Trees (BST, Trie, Heap)
    - Graphs (BFS, DFS, Union-Find)
    - Dynamic Programming
    - Sliding Window / Two Pointers
    - Binary Search, Backtracking, Recursion
2. Databases
    - SQL in detail
    - No SQL
    - Graph DB
3. LLD
    - OOPs
    - Design Patterns
4. HLD
    - Load balancing, caching, DBs, microservices

5. AWS
6. Frontend
    - Vue
    - React core concepts
7. Operating System
8. Networking
9. AI
    - Generative AI
    - Agent AI
10. Language
    - Dotnet
    - Python
    - Java

# %% [markdown]
# # 1. Design Pattern Resources

# %%
- For UML Diagram:  https://sparxsystems.com/resources/tutorials/uml2/class-diagram.html
- For Class Code Relation (In java): https://github.com/SouravAggarwal/design-patterns/blob/main/design-patterns/src/main/java/org/prateek/Basics/UML/AggregationExample.java

# %% [markdown]
# # 2. System Design Resources

# %%
- Cheet Sheet: https://github.com/SouravAggarwal/system-design-primer or https://github.com/donnemartin/system-design-primer
- Paid Course: https://www.educative.io/courses/grokking-the-system-design-interview/getting-ready-for-the-system-design-interview

Books:
- Available in same directory
  1.System Design Interview An Insider’s Guide by Alex Xu (z-lib.org)
  2.Grokking-the-system-design-interview

# %% [markdown]
# # 3. HR/ Leadership Principles

# %%
Behavioral & HR Round
    - Conflict resolution
    - Leadership
    - Failure stories
    - Teamwork
    - Projects / Achievements

# %%
- https://www.amazon.jobs/content/en/our-workplace/leadership-principles

# %%
# Things to cover
-  Authentication and Authorization
- integer and character space consumption and conversion from bytes/ bits to MB.

# %%
# Topics remiaing
    - Graph DB
