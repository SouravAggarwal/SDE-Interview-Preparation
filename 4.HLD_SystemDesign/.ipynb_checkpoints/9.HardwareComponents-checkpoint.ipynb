# %%
Content
1. Redis

# %%
1. Redis
    - Redis stores data in RAM
    - Redis uses single thread, in contrast to DB which uses multi-thread it slows down the process by locks.
    - It uses IO Multi-plexing        

0.3ns   Register
0.9ns   L1 Cache
2.8ns   L2 Cache
12.9ns   L3 Cache
120ns     RAM   <-- Redis uses RAM, not disk
50-150µs  SSD
1-10ms    HDD

# %%
Operation          | Latency
-----------------------------------
In-memory (local)  | ~10–100 ns
Redis (network)    | ~0.2–1 ms
DB query           | ~5–50 ms
